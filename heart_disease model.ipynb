# %%
from pandas import *
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=read_csv('/content/sample_data/framingham.csv')

# %%
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (3656, 16)

# %%
df.corr()['TenYearCHD']
# Out:
# male               0.091745
# age                0.233810
# education         -0.063068
# currentSmoker      0.019176
# cigsPerDay         0.052159
# BPMeds             0.089116
# prevalentStroke    0.048351
# prevalentHyp       0.181556
# diabetes           0.093397
# totChol            0.091127
# sysBP              0.222885
# diaBP              0.150342
# BMI                0.081931
# heartRate          0.020523
# glucose            0.121942
# TenYearCHD         1.000000
# Name: TenYearCHD, dtype: float64

# %%
x=df.drop(columns=['TenYearCHD'])

# %%
x
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4231     1   58        3.0              0         0.0     0.0
# 4232     1   68        1.0              0         0.0     0.0
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
y=df.TenYearCHD

# %% [markdown]
# normalising the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x_stand=sc.fit_transform(x)

# %%
x_stand
# Out:
# array([[ 1.11982472, -1.23335117,  1.97575158, ...,  0.29168785,
#          0.35633992, -0.20312694],
#        [-0.8929969 , -0.41559058,  0.01979497, ...,  0.7246142 ,
#          1.60828949, -0.24495595],
#        [ 1.11982472, -0.1819447 , -0.95818334, ..., -0.10926099,
#         -0.06097661, -0.49592996],
#        ...,
#        [ 1.11982472,  0.05170118, -0.95818334, ...,  0.04570696,
#         -0.81214636,  0.17333408],
#        [ 1.11982472,  0.16852412,  0.99777327, ..., -1.49413337,
#         -0.89560966, -0.57958797],
#        [-0.8929969 ,  0.28534706,  0.01979497, ..., -1.06120701,
#          0.35633992,  1.05174313]])

# %% [markdown]
# saving normalising model

# %%
import pickle
with open("/content/sample_data/scaler_of_heart_model.sav",'wb')as f:
  pickle.dump(sc,f)

# %% [markdown]
# balancing the datset

# %%
from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE()

# %%
x_resample,y_resample=sm.fit_resample(x_stand,y)

# %%
y_resample.value_counts()
# Out:
# TenYearCHD
# 0    3099
# 1    3099
# Name: count, dtype: int64

# %% [markdown]
# train test split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_resample,y_resample,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# logistic regression

# %%
logistic_model=LogisticRegression()

# %%
logistic_model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
logistic_model.score(x_train,y_train)
# Out:
# 0.6892577224527432

# %%
logistic_model.score(x_test,y_test)
# Out:
# 0.693010752688172

# %% [markdown]
# support vector machine

# %%
from sklearn.svm import SVC
svm_model=SVC()

# %%
svm_model.fit(x_train,y_train)
# Out:
# SVC()

# %%
predict=svm_model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(predict,y_test))
print(classification_report(predict,y_test))
# Out:
# [[675 239]
#  [254 692]]
#               precision    recall  f1-score   support
#
#            0       0.73      0.74      0.73       914
#            1       0.74      0.73      0.74       946
#
#     accuracy                           0.73      1860
#    macro avg       0.73      0.74      0.73      1860
# weighted avg       0.74      0.73      0.73      1860

# %%
# Corrected code to calculate the score using the test data
svm_model.score(x_test,y_test)
# Out:
# 0.7349462365591398

# %% [markdown]
# decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
decision_model=DecisionTreeClassifier(random_state=42)

# %%
decision_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
predict=decision_model.predict(x_test)

# %%
print(confusion_matrix(predict,y_test))
print(classification_report(predict,y_test))
# Out:
# [[722 147]
#  [207 784]]
#               precision    recall  f1-score   support
#
#            0       0.78      0.83      0.80       869
#            1       0.84      0.79      0.82       991
#
#     accuracy                           0.81      1860
#    macro avg       0.81      0.81      0.81      1860
# weighted avg       0.81      0.81      0.81      1860

# %%
decision_model.score(x_test,y_test)
# Out:
# 0.8096774193548387

# %% [markdown]
# xgboost

# %%
# XGBoost Example
from xgboost import XGBClassifier
xgboost_model = XGBClassifier( n_estimators=300,
    max_depth=4,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    gamma=1,
    reg_alpha=0.1,
    reg_lambda=1,
    objective='binary:logistic',
    eval_metric='auc',
    random_state=42)
xgboost_model.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               gamma=1, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=4, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
# XGBoost Example
from xgboost import XGBClassifier
xgboost_model = XGBClassifier( n_estimators=300,
    max_depth=4,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    gamma=1,
    reg_alpha=0.1,
    reg_lambda=1,
    objective='binary:logistic',
    eval_metric='auc',
    random_state=42)
xgboost_model.fit(x_train,y_train)
predict=xgboost_model.predict(x_test)

# %%
print(confusion_matrix(predict,y_test))
print(classification_report(predict,y_test))
# Out:
# [[818 142]
#  [111 789]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87       960
#            1       0.85      0.88      0.86       900
#
#     accuracy                           0.86      1860
#    macro avg       0.86      0.86      0.86      1860
# weighted avg       0.86      0.86      0.86      1860

# %%
xgboost_model.score(x_test,y_test)
# Out:
# 0.863978494623656

# %%
with open('/content/sample_data/heart_model.pk1','wb') as f:
  pickle.dump(xgboost_model,f)

# %% [markdown]
# ANN

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Dropout

# %%
model2=Sequential()

# %%
model2.add(Dense(32,activation='relu',input_shape=(15,)))
model2.add(Dense(16,activation='relu'))
model2.add(Dense(8,activation='relu'))
model2.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model2.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['Accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
earlystoping=EarlyStopping(monitor='val_loss',patience=6,restore_best_weights=True)

# %%
model2.fit(x_train,y_train,epochs=1000,validation_data=(x_test,y_test),callbacks=[earlystoping])
# Out:
# Epoch 1/1000
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - Accuracy: 0.5418 - loss: 0.7568 - val_Accuracy: 0.6527 - val_loss: 0.6254
# Epoch 2/1000
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Accuracy: 0.6641 - loss: 0.6172 - val_Accuracy: 0.6871 - val_loss: 0.5962
# Epoch 3/1000
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Accuracy: 0.6956 - loss: 0.5872 - val_Accuracy: 0.6957 - val_loss: 0.5832
# Epoch 4/1000
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.6887 - loss: 0.5855 - val_Accuracy: 0.7086 - val_loss: 0.5753
# Epoch 5/1000
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - Accuracy: 0.7074 - loss: 0.5716 - val_Accuracy: 0.7091 - val_loss: 0.5731
# Epoch 6/1000
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Accuracy: 0.7189 - loss: 0.5551 - val_Accuracy: 0.7108 - val_loss: 0.5679
# Epoch 7/1000
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Accuracy: 0.7229 - loss: 0.5572 - val_Accuracy: 0.7237 - val_loss: 0.5627
# Epoch 8/1000
# ...

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
ylogpred=model2.predict(x_test)
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# how to select appropriate optimizer

# %%
# !pip install keras-tuner
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 2.8 MB/s eta 0:00:00
# ...

# %%
import keras_tuner as kt

# %%
def build_model(hp):
  model10=Sequential()
  counter=0
  for i in range(hp.Int('num_layers',min_value=1,max_value=10)):
    if counter==0:
      model10.add(Dense(hp.Int(f'units_{i}', min_value=64, max_value=512, step=64),activation=hp.Choice('activation'+str(i),values=['relu','tanh','sigmoid','elu','selu']),input_shape=(15,)))
      model10.add(Dropout(hp.Float('dropout_' + str(i), 0.0, 0.5, step=0.1)))

    else:
      model10.add(Dense(hp.Int(f'units_{i}', min_value=64, max_value=512, step=64),activation=hp.Choice('activation'+str(i),values=['relu','tanh','sigmoid','elu','selu'])))
      model10.add(Dropout(hp.Float('dropout_' + str(i), 0.0, 0.5, step=0.1)))

    counter+=1
  model10.add(Dense(1,activation='sigmoid'))
  model10.compile(optimizer=hp.Choice('optimizer',values=['rmsprop','adam','sgd','adamax','adadelta']),loss='binary_crossentropy',metrics=['Accuracy'])
  return model10

# %%
tuner=kt.RandomSearch(build_model,objective='val_Accuracy',max_trials=10,directory='tuner_dir',project_name='final3')

# %%
tuner.search(x_train,y_train,epochs=10,validation_data=(x_test,y_test))
# Out:
# Trial 10 Complete [00h 00m 17s]
# val_Accuracy: 0.7102150321006775
#
# Best val_Accuracy So Far: 0.750537633895874
# Total elapsed time: 00h 04m 54s

# %%
tuner.get_best_hyperparameters()[0].values
# Out:
# {'num_layers': 7,
#  'units_0': 448,
#  'activation0': 'tanh',
#  'dropout_0': 0.1,
#  'optimizer': 'adam',
#  'units_1': 192,
#  'activation1': 'relu',
#  'dropout_1': 0.30000000000000004,
#  'units_2': 384,
#  'activation2': 'relu',
#  'dropout_2': 0.2,
#  'units_3': 384,
#  'activation3': 'elu',
#  'dropout_3': 0.30000000000000004,
#  'units_4': 384,
#  'activation4': 'sigmoid',
#  'dropout_4': 0.30000000000000004,
#  'units_5': 256,
#  'activation5': 'tanh',
#  'dropout_5': 0.1,
#  'units_6': 192,
#  'activation6': 'elu',
#  'dropout_6': 0.2,
#  'units_7': 64,
#  'activation7': 'elu',
#  'dropout_7': 0.30000000000000004,
#  'units_8': 64,
#  'activation8': 'sigmoid',
#  'dropout_8': 0.0,
#  'units_9': 384,
#  'activation9': 'selu',
#  'dropout_9': 0.2}

# %%
model11=tuner.get_best_models(num_models=1)[0]

# %%
best_hp = tuner.get_best_hyperparameters()[0]
print(best_hp.values)
# Out:
# {'num_layers': 7, 'units_0': 448, 'activation0': 'tanh', 'dropout_0': 0.1, 'optimizer': 'adam', 'units_1': 192, 'activation1': 'relu', 'dropout_1': 0.30000000000000004, 'units_2': 384, 'activation2': 'relu', 'dropout_2': 0.2, 'units_3': 384, 'activation3': 'elu', 'dropout_3': 0.30000000000000004, 'units_4': 384, 'activation4': 'sigmoid', 'dropout_4': 0.30000000000000004, 'units_5': 256, 'activation5': 'tanh', 'dropout_5': 0.1, 'units_6': 192, 'activation6': 'elu', 'dropout_6': 0.2, 'units_7': 64, 'activation7': 'elu', 'dropout_7': 0.30000000000000004, 'units_8': 64, 'activation8': 'sigmoid', 'dropout_8': 0.0, 'units_9': 384, 'activation9': 'selu', 'dropout_9': 0.2}

# %%
model11.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 448)            │         7,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 448)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 192)            │        86,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 192)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 384)            │        74,112 │
# ...

# %%
from keras.callbacks import EarlyStopping
early_stoping=EarlyStopping(monitor='val_loss',patience=10,restore_best_weights=True)

# %%
history=model11.fit(x_train,y_train,epochs=1000,validation_data=(x_test,y_test),callbacks=[early_stoping],initial_epoch=10)
# Out:
# Epoch 11/1000
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - Accuracy: 0.7542 - loss: 0.5186 - val_Accuracy: 0.7618 - val_loss: 0.5063
# Epoch 12/1000
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - Accuracy: 0.7759 - loss: 0.4997 - val_Accuracy: 0.7839 - val_loss: 0.4915
# Epoch 13/1000
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - Accuracy: 0.7831 - loss: 0.4882 - val_Accuracy: 0.7871 - val_loss: 0.4783
# Epoch 14/1000
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - Accuracy: 0.7829 - loss: 0.4904 - val_Accuracy: 0.7828 - val_loss: 0.4984
# Epoch 15/1000
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - Accuracy: 0.7827 - loss: 0.4916 - val_Accuracy: 0.7876 - val_loss: 0.4748
# Epoch 16/1000
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - Accuracy: 0.7859 - loss: 0.4643 - val_Accuracy: 0.7935 - val_loss: 0.4649
# Epoch 17/1000
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - Accuracy: 0.7897 - loss: 0.4597 - val_Accuracy: 0.7914 - val_loss: 0.4576
# Epoch 18/1000
# ...

# %%
y_log=model11.predict(x_test)
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
predicted=np.where(y_log>0.5,1,0)

# %%
confusion_matrix(y_test,predicted)
# Out:
# array([[756, 173],
#        [ 48, 883]])

# %%
print(classification_report(y_test,predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87       929
#            1       0.84      0.95      0.89       931
#
#     accuracy                           0.88      1860
#    macro avg       0.89      0.88      0.88      1860
# weighted avg       0.89      0.88      0.88      1860

# %%
history.history
# Out:
# {'Accuracy': [0.7445827722549438,
#   0.7602581977844238,
#   0.7706316113471985,
#   0.7770861983299255,
#   0.786076545715332,
#   0.7840018272399902,
#   0.7918395400047302,
#   0.8029045462608337,
#   0.8077455163002014,
#   0.8077455163002014,
#   0.8188105225563049,
#   0.8123559355735779,
#   0.8261871933937073,
#   0.8245735168457031,
#   0.8167358040809631,
#   0.8441678285598755,
#   0.8363301157951355,
#   0.8443983197212219,
#   0.8437067866325378,
#   0.8411710262298584,
#   0.8450899124145508,
#   0.849469780921936,
#   0.8570770025253296,
#   0.8681420087814331,
#   0.8614568710327148,
#   0.8639926314353943,
#   0.8697556257247925,
#   0.8686030507087708,
#   0.8702166676521301,
#   0.8785154223442078,
#   0.8826647996902466,
#   0.8796680569648743,
#   0.888658344745636,
#   0.8849700093269348,
#   0.8847395181655884,
#   0.8928077220916748,
#   0.8840479254722595,
#   0.8932687640190125,
#   0.8958045244216919,
#   0.9004149436950684,
#   0.9004149436950684,
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.plot(history.history['Accuracy'])
plt.title('model_aaccracy')
plt.subplot(2,2,2)
plt.plot(history.history['val_Accuracy'])
plt.title('validation accuracy')
plt.subplot(2,2,3)
plt.plot(history.history['loss'])
plt.title('loss')
plt.subplot(2,2,4)
plt.plot(history.history['val_loss'])
plt.title('validation loss')
plt.show()

# %%
plt.title('model_aaccracy')
plt.plot(history.history['Accuracy'],label='trainig acuuracy')
plt.plot(history.history['val_Accuracy'],label='test accuracy')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py'>

# %%
model11.save('/content/sample_data/heart_disease_ann_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from keras.saving import save_model

save_model(model11, '/content/sample_data/heart_ann_model.keras')
